# %%
import spacy
import re

# %%
# CYTOWANIA -> CYTOWANIE
re1 = r'\((\s*CYTOWANIE[\,\.\s\u2013\u2212:;-]*)*\)'
# (...) -> ""
re2 = r'\([\w\s\.\,\u2013\u2212\+-=×\*<>&°^%\$#@!?\'\"\\]*\)[\s]*' 
re3 = r'\[[\w\s\.\,\u2013\u2212\+-=×\*<>&°^%\$#@!?\'\"\\]*\][\s]*' 
# "    " -> " " && x.X -> x. X
re4 = r'(?<=[.])(?=[^\d])(?=[^\s])(?=[^a-z])'
re5 = r'(?<=[,])(?=[^\d])(?=[^\s])'
re6 = r'(?<!\d)\n'
re7 = r'(\s\s+)'

for i in range(20):
    path_file_in = "inp/1 ("+ str(i+1) + ").txt"
    path_file_out = "out/1 ("+ str(i+1) + ").txt"  
    
    file_in = open(path_file_in, "r", encoding='ISO-8859-1')
    file_out = open(path_file_out, "w+", encoding='utf-8')
    
    for line in file_in:
        line = re.sub("(%s|%s|%s|%s)" % (re4,re5,re6,re7), r' ', re.sub("(%s|%s)" % (re2,re3), r'', re.sub("(%s)" % (re1), r' CYTOWANIE ', line)))
        file_out.write(line)
        
    file_in.close()
    file_out.close()

# %%
for i in range(20):
    file = open("out/1 ("+ str(i+1) +").txt", "r", encoding = 'utf-8')
    out_tag = open("output_tag/1 ("+ str(i+1) +").txt", "w+", encoding = 'utf-8')
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(file.read())

    l = ["(", ")", "[", "]", "CYTOWANIE"]
    i = 1
    for token in doc:
        if i+1 <= len(doc):
            t1 = doc[i]

        if t1.text == 'CYTOWANIE':
            #print(token.text, token.lemma_, token.pos_, token.tag_  + " B")
            line = str(token.text + "\t" + token.lemma_ + "\t" +  token.tag_  + "\t" +  "B\n")
            out_tag.writelines(str(line))
        else:
            if token.text not in l:
                #print(token.text, token.lemma_, token.pos_, token.tag_ + " O")
                if token.text == ".":
                    line = str(token.text + "\t" +  token.lemma_ + "\t"  +  token.tag_ + "\t" +  "O\n\n")
                else:
                    line = str(token.text + "\t" +  token.lemma_ + "\t"  +  token.tag_ + "\t" +  "O\n")
                out_tag.writelines(str(line))
        i += 1

    file.close()
    out_tag.close()

# %%
import re
re1 = r'(?<=[.])(?=[^\d])(?=[^\s])(?=[^a-z])'
re2 = r'(?<=[,])(?=[^\d])(?=[^\s])'
re3 = r'(?<!\d)\n'
re4 = r'(\s\s+)'
sentence = '''To jest zdanie.Tu       zaczyna się nowe   zdanie.I tu     też, a to jest 
liczba 124.24 i druga 2.1,po przecinku tez przyda sie odstep,a np. tu nie potrzeba 
dodawac nowej spacji. Bo tu spacja już jest 2,4,5 dobrze użyta. Natomiast jeżeli jest slowo.slowo, 
czyli drugie jest z małej to zostawiamy jak jest na wypadek jakiś wzorów itp.itd.Co innego słowo.Słowo'''

re.sub("(%s|%s|%s|%s)" % (re1, re2, re3, re4), r' ', sentence)
# Out:
# 'To jest zdanie. Tu zaczyna się nowe zdanie. I tu też, a to jest liczba 124.24 i druga 2.1, po przecinku tez przyda sie odstep, a np. tu nie potrzeba dodawac nowej spacji. Bo tu spacja już jest 2,4,5 dobrze użyta. Natomiast jeżeli jest slowo.slowo, czyli drugie jest z małej to zostawiamy jak jest na wypadek jakiś wzorów itp.itd. Co innego słowo. Słowo'

# %%
for i in range(29):
    out_tag = open("output_tag/1 ("+ str(i+1) +").txt", "r", encoding = 'utf-8')
    ready_for_crf = open("ready_for_crf/1 ("+ str(i+1) +").txt", "w+", encoding = 'utf-8')
   
    lines = out_tag.readlines()
    line_count = 0

    for line in lines:
        count = 0
        line_count += 1
        x = True
        #print(line)
        for l in line:
            if l == "\t" and x:
                count +=1
                x = False
            elif l != " ":
                x = True

        #print(count)

        if count != 3 and count != 0:
            print(f"Błąd w linii: ", line_count)
        else:
            ready_for_crf.write(line)

    out_tag.close()
    ready_for_crf.close()
# Out:
# Błąd w linii:  507
# Błąd w linii:  511
# Błąd w linii:  550
# Błąd w linii:  688
# Błąd w linii:  2162
# Błąd w linii:  4916
# Błąd w linii:  5007
# Błąd w linii:  1699
# Błąd w linii:  3653
# Błąd w linii:  4381
# Błąd w linii:  4443
# Błąd w linii:  4464
# Błąd w linii:  4586
# Błąd w linii:  6195
# Błąd w linii:  1658
# Błąd w linii:  4231
# Błąd w linii:  857
# Błąd w linii:  858
# Błąd w linii:  1043
# Błąd w linii:  1044
# Błąd w linii:  1166
# Błąd w linii:  1167
# Błąd w linii:  1384
# Błąd w linii:  1385
# Błąd w linii:  2406
# Błąd w linii:  2409
# Błąd w linii:  2410
# Błąd w linii:  3059
# Błąd w linii:  3060
# Błąd w linii:  3971
# Błąd w linii:  3972
# Błąd w linii:  4259
# Błąd w linii:  4260
# Błąd w linii:  292
# Błąd w linii:  1028
# Błąd w linii:  1052
# Błąd w linii:  1081
# Błąd w linii:  1131
# Błąd w linii:  1181
# Błąd w linii:  1445
# Błąd w linii:  1575
# Błąd w linii:  1584
# Błąd w linii:  1660
# Błąd w linii:  1708
# Błąd w linii:  3253
# Błąd w linii:  5149
# Błąd w linii:  246
# Błąd w linii:  313
# Błąd w linii:  612
# Błąd w linii:  936
# Błąd w linii:  2779
# Błąd w linii:  3165
# Błąd w linii:  3246
# Błąd w linii:  3268
# Błąd w linii:  3293
# Błąd w linii:  3321
# Błąd w linii:  3369
# Błąd w linii:  4800
# Błąd w linii:  337
# Błąd w linii:  393
# Błąd w linii:  716
# Błąd w linii:  717
# Błąd w linii:  1390
# Błąd w linii:  1392
# Błąd w linii:  1394
# Błąd w linii:  1397
# Błąd w linii:  1399
# Błąd w linii:  1401
# Błąd w linii:  1404
# Błąd w linii:  1406
# Błąd w linii:  1408
# Błąd w linii:  1410
# Błąd w linii:  1412
# Błąd w linii:  1416
# Błąd w linii:  1418
# Błąd w linii:  1768
# Błąd w linii:  1773
# Błąd w linii:  1778
# Błąd w linii:  1786
# Błąd w linii:  1897
# Błąd w linii:  1941
# Błąd w linii:  1979
# Błąd w linii:  2066
# Błąd w linii:  2085
# Błąd w linii:  2086
# Błąd w linii:  2100
# Błąd w linii:  2108
# Błąd w linii:  2132
# Błąd w linii:  2149
# Błąd w linii:  2265
# Błąd w linii:  2271
# Błąd w linii:  2277
# Błąd w linii:  2490
# Błąd w linii:  2521
# Błąd w linii:  2535
# Błąd w linii:  2564
# Błąd w linii:  2574
# Błąd w linii:  2581
# Błąd w linii:  2588
# Błąd w linii:  2613
# Błąd w linii:  2617
# Błąd w linii:  2648
# Błąd w linii:  2654
# Błąd w linii:  2664
# Błąd w linii:  2762
# Błąd w linii:  2764
# Błąd w linii:  2772
# Błąd w linii:  2774
# Błąd w linii:  2993
# Błąd w linii:  3163
# Błąd w linii:  3165
# Błąd w linii:  3167
# Błąd w linii:  3169
# Błąd w linii:  3171
# Błąd w linii:  3173
# Błąd w linii:  3175
# Błąd w linii:  3177
# Błąd w linii:  3179
# Błąd w linii:  3181
# Błąd w linii:  3183
# Błąd w linii:  3185
# Błąd w linii:  3450
# Błąd w linii:  3527
# Błąd w linii:  4462
# Błąd w linii:  4463
# Błąd w linii:  4542
# Błąd w linii:  4866
# Błąd w linii:  4892
# Błąd w linii:  4907
# Błąd w linii:  4908
# Błąd w linii:  4918
# Błąd w linii:  4950
# Błąd w linii:  4951
# Błąd w linii:  4960
# Błąd w linii:  4961
# Błąd w linii:  4969
# Błąd w linii:  5067
# Błąd w linii:  5068
# Błąd w linii:  5230
# Błąd w linii:  5240
# Błąd w linii:  5241
# Błąd w linii:  5384
# Błąd w linii:  5738
# Błąd w linii:  5739
# Błąd w linii:  5780
# Błąd w linii:  5781
# Błąd w linii:  5801
# Błąd w linii:  6037

# %%
print("– or -")

ord('')


chr(137)
# Out:
# – or -
# '\x89'

# %%
s = ''' Czesc (ell ° ) â [â+â] '''

# CYTOWANIA -> CYTOWANIE
re1 = r'\((\s*CYTOWANIE[\,\.\s\u2013\u2212:;-]*)*\)'
# (...) -> ""
re2 = r'\([\w\s\.\,\u2013\u2212\+-=×\*<>&^%\°$#@!?\'\"\\]*\)[\s]*' 
re3 = r'\[[\w\s\.\,\u2013\u2212\+-=×\*<>&^%\°$#@!?\'\"\\]*\][\s]*' 
# "    " -> " " && x.X -> x. X
re4 = r'(?<=[.])(?=[^\d])(?=[^\s])(?=[^a-z])'
re5 = r'(?<=[,])(?=[^\d])(?=[^\s])'
re6 = r'(?<!\d)\n'
re7 = r'(\s\s+)'

l = re.sub("(%s|%s|%s|%s)" % (re4,re5,re6,re7), r' ', re.sub("(%s|%s)" % (re2,re3), r'', re.sub("(%s)" % (re1), r' CYTOWANIE ', s)))
print(l)
# Out:
#  Czesc â []
